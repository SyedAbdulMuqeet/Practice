# %%
import pandas as pd

# %%
import numpy as np

# %%
import tensorflow

# %%
from tensorflow.keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 432s 38us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
len(train_labels)
# Out:
# 60000

# %%
from tensorflow.keras import models

# %%
from tensorflow.keras import layers

# %%
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.2547 - accuracy: 0.9264
# Epoch 2/5
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.1025 - accuracy: 0.9701
# Epoch 3/5
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.0674 - accuracy: 0.9805
# Epoch 4/5
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.0490 - accuracy: 0.9851
# Epoch 5/5
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0364 - accuracy: 0.9894

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc: 0.982

# %%
network.fit(train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0272 - accuracy: 0.9920
# Epoch 2/10
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.0219 - accuracy: 0.9934
# Epoch 3/10
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0159 - accuracy: 0.9955
# Epoch 4/10
# 60000/60000 [==============================] - 8s 127us/sample - loss: 0.0130 - accuracy: 0.9963
# Epoch 5/10
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.0094 - accuracy: 0.9974
# Epoch 6/10
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.0072 - accuracy: 0.9980
# Epoch 7/10
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0057 - accuracy: 0.9984
# Epoch 8/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0048 - accuracy: 0.9987
# Epoch 9/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0036 - accuracy: 0.9991
# Epoch 10/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0026 - accuracy: 0.9993

# %%
network.fit(train_images, train_labels, epochs=20, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.0021 - accuracy: 0.9995
# Epoch 2/20
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.0020 - accuracy: 0.9995
# Epoch 3/20
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0013 - accuracy: 0.9997
# Epoch 4/20
# 60000/60000 [==============================] - 7s 115us/sample - loss: 8.8006e-04 - accuracy: 0.9997
# Epoch 5/20
# 60000/60000 [==============================] - 7s 112us/sample - loss: 8.2661e-04 - accuracy: 0.9998
# Epoch 6/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 7.5434e-04 - accuracy: 0.9998
# Epoch 7/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 5.8710e-04 - accuracy: 0.9999
# Epoch 8/20
# 60000/60000 [==============================] - 7s 113us/sample - loss: 3.6820e-04 - accuracy: 0.9999
# Epoch 9/20
# 60000/60000 [==============================] - 7s 112us/sample - loss: 4.1171e-04 - accuracy: 0.9999
# Epoch 10/20
# 60000/60000 [==============================] - 8s 127us/sample - loss: 4.2281e-04 - accuracy: 0.9999
# Epoch 11/20
# 60000/60000 [==============================] - 8s 125us/sample - loss: 2.0749e-04 - accuracy: 0.9999
# Epoch 12/20
# 60000/60000 [==============================] - 7s 120us/sample - loss: 1.6595e-04 - accuracy: 1.0000
# Epoch 13/20
# 60000/60000 [==============================] - 7s 121us/sample - loss: 1.5011e-04 - accuracy: 1.0000
# Epoch 14/20
# 60000/60000 [==============================] - 8s 127us/sample - loss: 1.5520e-04 - accuracy: 0.9999
# Epoch 15/20
# 60000/60000 [==============================] - 8s 126us/sample - loss: 7.4730e-05 - accuracy: 1.0000
# Epoch 16/20
# 60000/60000 [==============================] - 7s 116us/sample - loss: 9.7095e-05 - accuracy: 1.0000
# Epoch 17/20
# 60000/60000 [==============================] - 7s 118us/sample - loss: 6.5598e-05 - accuracy: 1.0000
# Epoch 18/20
# 60000/60000 [==============================] - 7s 124us/sample - loss: 3.0702e-05 - accuracy: 1.0000
# Epoch 19/20
# 60000/60000 [==============================] - 8s 141us/sample - loss: 1.1392e-04 - accuracy: 1.0000
# Epoch 20/20
# 60000/60000 [==============================] - 8s 134us/sample - loss: 1.2294e-05 - accuracy: 1.0000
